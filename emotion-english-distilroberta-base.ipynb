# %%
# return all emotion scores
from transformers import pipeline, logging

logging.set_verbosity_error()

text = "I love this!"

classifier = pipeline("text-classification", model="j-hartmann/emotion-english-distilroberta-base", return_all_scores=True)
classifier(text)
# Out:
# c:\Users\admin\OneDrive - NEOM\Desktop\imdb_sentiment\.conda\lib\site-packages\transformers\pipelines\text_classification.py:105: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# [[{'label': 'anger', 'score': 0.004419781267642975},
#   {'label': 'disgust', 'score': 0.001611992483958602},
#   {'label': 'fear', 'score': 0.00041385178337804973},
#   {'label': 'joy', 'score': 0.9771687984466553},
#   {'label': 'neutral', 'score': 0.005764597095549107},
#   {'label': 'sadness', 'score': 0.0020923905540257692},
#   {'label': 'surprise', 'score': 0.008528684265911579}]]

# %%
# return highest emotion with score
from transformers import pipeline, logging

logging.set_verbosity_error()

text = "I love this!"

classifier = pipeline("text-classification", model="j-hartmann/emotion-english-distilroberta-base")
classifier(text)
# Out:
# [{'label': 'joy', 'score': 0.9771687984466553}]

# %%
# return highest emotion label only
from transformers import pipeline, logging

logging.set_verbosity_error()

text = "I love this!"

classifier = pipeline("text-classification", model="j-hartmann/emotion-english-distilroberta-base")
result = classifier(text)

emotion_label = result[0]['label']

print(emotion_label)
# Out:
# joy

# %%
# apply the sentiment analysis to the hotel review dataset
import pandas as pd
from transformers import pipeline, logging

logging.set_verbosity_error()

df = pd.read_csv('input\document-nlp.csv') # change the filename to your .csv file name and location

for index, row in df.iterrows():
    text = row['sentence_split_text']
    classifier = pipeline("text-classification", model="j-hartmann/emotion-english-distilroberta-base")
    result = classifier(text)
    emotion_label = result[0]['label']
    
    # print the sentence and emotion class
    print(text)
    print("emotion:", emotion_label)
    print()
# Out:
# c:\Users\admin\OneDrive - NEOM\Desktop\imdb_sentiment\.conda\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# decent room affordable price downtown seattle went visit friend seattle mid-september game husky stadium
# emotion: neutral
#
# chose place looking various websites affordable hotel room downtown
# emotion: surprise
#
# place fit bill.the room average typical midgrade hotel
# emotion: neutral
#
# clean
# emotion: neutral
#
# real downside walls did not hold sound outside
# emotion: surprise
#
# heard lot noise rooms outside
# emotion: surprise
#
# fortunately slept well.the staff nice willing hold bags hours checked out.there restaurant hotel ate breakfast food pretty good.this hotel 3 blocks westlake center terminus s lake union streetcar monorail seattle center space needle area
# emotion: sadness
#
# blocks pike place market hill
# emotion: surprise
#
# great location laughable rooms booked flights seattle package got great deal
# emotion: joy
#
# 660 people nights airfare did n't choice stay
# emotion: neutral
#
# hotel old kind stinky
# emotion: neutral
#
# refused elevator bit decrepit smelled vomit stairways smelled like pee room quite clean bare
# emotion: disgust
#
# walked city times location hotel superb
# emotion: joy
#
# belltown tons cute places eat drink right downtown plethora chain clothing stores
# emotion: joy
#
# n't know stay certainly sufficient low budget minute long weekend trip
# emotion: surprise
#
# great cozy hoitel location great right westin mcdonalds walking distance downtown monorail
# emotion: joy
#
# outside looks like older small motel inside good mid-level think holiday inn
# emotion: neutral
#
# resturant bit pricy food good quality atmosphere great wood burning fireplace
# emotion: joy
#
# nice place gray day seattle.i booked airline milage points highly reccommend
# emotion: joy
#
# not bad price great bargain downtown seattle.it old clean little noisy
# emotion: sadness
#
# location great
# emotion: joy
#
# staff friendlly
# emotion: neutral
#
# able leave car parking lot hours checked real nice bonus
# emotion: joy
#
# just need place sleep night bargain price
# emotion: neutral
#
# want amenities
# emotion: neutral
#
# stay
# emotion: neutral
#
# walk pike place market breakfast seattle native pleased bid win sixth avenue inn onpriceline
# emotion: joy
#
# motel just motel right middle downtown seattle
# emotion: neutral
#
# think remember seattle world fairin 1962
# emotion: neutral
#
# bit dated bathroom did n't shelf space imo overlook type thing amazing safe location
# emotion: surprise
#
# think returned 60 drive easy access i-5 important location unbeatable no long waits elevators walks endless lobbies
# emotion: surprise
#
# poof door way pike place market belltown downtown monorail
# emotion: surprise
#
# pro football baseball venues 15 min bus ride south
# emotion: neutral
#
# exploring downtown seattle goal want play dollarsinstead paying high rise view try motel
# emotion: neutral
#
# come n't understand bad reviews
# emotion: neutral
#
# hotel simple got exactly need nice confortable bed clean bathroom excellent price
# emotion: neutral
#
# near walked pike place market monorail
# emotion: neutral
#
# not book false information family just finished 7-day alaskan cruise
# emotion: neutral
#
# looking hotel seattle wa shuttle service pier hotel hotel airport place leave luggage 5-6 hrs went site seeing downtown
# emotion: surprise
#
# booking company particular hotel assured criteria met hotel booked room just store luggage 115
# emotion: neutral
#
# ended no travel accomodations hotel airport
# emotion: neutral
#
# ended having 2 taxis destinations
# emotion: sadness
#
# needless say angry extra 80 hotel
# emotion: anger
#
# hotel manager not available phone
# emotion: sadness
#
# customer service reps finally got called 5-6 times sent email website
# emotion: surprise
#
# matter resolved hopefully
# emotion: neutral
#
# said reimburse taxi fares believe
# emotion: neutral
#
# advice situation grab taxi airport 30 flat fee downtown seatac airport check luggage early ride-on bus downtown 1.50 way seniors free kids
# emotion: neutral
#
# free ride bus downtown seattle 7pm everyday
# emotion: neutral
#
# great location stayed property times
# emotion: joy
#
# like hotel location
# emotion: neutral
#
# hotel walking distance pike market al shopping seattle.the hotel parking pay small fee nightly rate payed 99
# emotion: neutral
#
# rooms clean good beds
# emotion: neutral
#
# experienced problems stays
# emotion: neutral
#
# budget booked hotel weekend november recommendation clean spartan room travel book not expecting seriously whelmed
# emotion: sadness
#
# room old tired felt dirty
# emotion: sadness
#
# slept fully clothed wore socks times
# emotion: neutral
#
# shower gross sink toilet new clean
# emotion: disgust
#
# pillows felt filled cotton balls bed creaked squeaked slightest movement did walls carpet stained did not feel lock door work
# emotion: sadness
#
# faced lovely strip club
# emotion: joy
#
# noise outside hotel expected downtown location noise inside hotel obscene
# emotion: fear
#
# people banging door 3 morning party room not mention felt right bed
# emotion: neutral
#
# walls general paper hear neighbours conversations watching tv.some staff friendly not sharpest location great walk
# emotion: joy
#
# not reccomend embarresed say stayed
# emotion: neutral
#
# sixth ave good budget choice downtown really enjoyed stay sixth ave inn
# emotion: joy
#
# room appeared newly renovated spacious modern
# emotion: joy
#
# hotel good location exploring seattle..we walked pikes place market 10 minutes downtown stores closer
# emotion: joy
#
# hotel restaurant gem..great food good prices nicer atmosphere expected
# emotion: joy
#
# hotel parking charge 10 night good downtown hotel
# emotion: neutral
#
# definately stay seattle
# emotion: neutral
#
# watch bait-and-switch room rates
# emotion: neutral
#
# rooms acceptable
# emotion: neutral
#
# having restaurant bar attached hotel helpful
# emotion: joy
#
# booked rooms hotels thankfully printed email confirmations showing rates.since initially no doubles available reserved single queen rollaway bed order sisters share room
# emotion: surprise
#
# arrived room queen beds cancelled rollaway.when checked management version rates 30 higher night room
# emotion: surprise
#
# certainly understand days multiple coupons memberships discounts misunderstanding occur
# emotion: neutral
#
# issue email printout took minutes convince fairly hostile desk adjust final bill.after returned home checked visa addition room charges single 34 charge
# emotion: anger
#
# turns never-seen never-used rollaway
# emotion: surprise
#
# having lengthy discussion long-distance phone called visa disputed charge.ok hotel bad management
# emotion: sadness
#
# affordable great location price boyfriend stayed 2 nights weekend getaway seattle 80us night needed
# emotion: joy
#
# staff friendly room clean
# emotion: neutral
#
# great budget hotel felt safe
# emotion: joy
#
# parking hotel 8/day
# emotion: neutral
#
# barely spent time room choose hotel convenient location things wanted
# emotion: surprise
#
# walking distance mcdonalds starbucks shopping centres short driving distances space needle emp
# emotion: neutral
#
# thing did n't like uncomfortably flat pillows bed
# emotion: fear
#
# got corner suite cold went play heating warmed
# emotion: neutral
#
# aside great value
# emotion: joy
#
# 2 recommendations loves bubble tea try gossip bubbletea chinatown
# emotion: joy
#
# tons bubble tea vancouver gossip best
# emotion: neutral
#
# thank previous posters board tip vegetarian lovers try araya thai vegetarian cuisine
# emotion: joy
#
# great price nice atmosphere generous portions
# emotion: joy
#
# basic hotel basic needs hotel perfect young travellers just need place sleep no needs far that.the rooms basic clean beds comfortable bathrooms clean hot water small showers desk staff friendly helpful not
# emotion: neutral
#
# essentially star hotel fair square.bring earplugs walls paper constant noise street rooms
# emotion: surprise
#
# just people room moving awake night creates loud creaking thumping sound step take.the area so-so
# emotion: surprise
#
# walking distance main areas attractions cab rides short cheap central location n't want walking immediate area surrounding hotel.the best feature hotel restaurant
# emotion: neutral
#
# staff amazingly friendly attentive fast
# emotion: neutral
#
# service notch
# emotion: neutral
#
# food great
# emotion: joy
#
# n't expect gourmet cusine hotel callibre
# emotion: surprise
#
# homestyle american food good oversized portions perfect sharing
# emotion: neutral
#
# stay hotel bring earplugs
# emotion: neutral
#
# average experience rooms sixth avenue inn included delta weekend getaway package seattle
# emotion: neutral
#
# centrally located inn not hotel choose nor seek again.the property old showing age
# emotion: sadness
#
# rooms cramped dark
# emotion: fear
#
# furnishings uncomfortable extremely hard beds rickety wicker patio furniture used place conventional chairs
# emotion: sadness
#
# high speed internet access provided 10.00 day port wired wall does not extend tiny nearby desk making computers difficult use
# emotion: neutral
#
# pay-as-you-go terminal lobby slow crippled worth money
# emotion: sadness
#
# not place stay plan work room.the desk staff helpful needed fax refax documents.breakfast restaurant surprisingly hearty not seek lived seattle
# emotion: joy
#
# breakfast not included room.in end property not best choice business vacation users good solution young people looking inexpensive rooms heart seattle
# emotion: sadness
#
# great value excellent staff 6th ave inn does n't look like special given hotels thatsurround
# emotion: joy
#
# low rise concrete motel like facade
# emotion: neutral
#
# n't fooled this.the hotel offers good value money right downtown seattle.plus points good rates locationhigh speed internet access rooms pay wifi lobby restaurant.good cozy bar excellent value restaurant.excellent helpful friendly staffminus points rooms little care wornmaid service little erratic friendly.overall excellent
# emotion: joy
#
# staff makes breaks hotel people atthe 6th ave inn not faulted
# emotion: anger
#
# desk/restaurant staff aresuperbbest tips try joe special breakfast food week seattle great public transport
# emotion: neutral
#
# n't pay 35 taxi airport
# emotion: sadness
#
# ride 194 stops westlake centre shortwalk hotel 1.25 peak 2.00 peak fare just quick plan trips n't easier certainly
# emotion: neutral
#
# o.k
# emotion: neutral
#
# place price recently stayed oct. 2004 4 nights
# emotion: neutral
#
# trip seattle not familiar area hotel
# emotion: neutral
#
# price 70 night room fair improvements nice hotel.upon arriving noticed hallways funny smell rooms clean
# emotion: surprise
#
# bathroom small hard 2 people ready
# emotion: neutral
#
# no mirror dresser difficult ready room husband showered
# emotion: surprise
#
# needed extra towels set person provided extras dresser
# emotion: neutral
#
# pillows lumpy no iron board room arrived.front desk staff accomodating helpful
# emotion: neutral
#
# ate restaurant twice good food service slow
# emotion: surprise
#
# ordered long island iced tea strong
# emotion: joy
#
# tried bartender fix handed sweet sour wash
# emotion: disgust
#
# did n't drink not charged commented not order kind drink ca n't handle liquor not say patron paying meals drinks.overall recommend short stay days nicer places located heart downtown want pay bit
# emotion: sadness
#
# disappointed sixth avenue inn nice place stay changes
# emotion: sadness
#
# staff hotel nice tried helpful
# emotion: neutral
#
# not stay sixth avenue inn nor recommend stay
# emotion: sadness
#
# significant changes need
# emotion: neutral
#
# assigned smoking room room
# emotion: neutral
#
# not told room smoking room making reservation
# emotion: neutral
#
# bed like marble slab
# emotion: neutral
#
# pillows lumpy spotted/dirty small
# emotion: disgust
#
# no extra blankets pillows room
# emotion: sadness
#
# mistook bath towel hand towel towels small
# emotion: neutral
#
# towels towels 1 person use
# emotion: neutral
#
# requested ironing board cover board dirty totally grossed
# emotion: disgust
#
# towel cover use
# emotion: neutral
#
# hotel continuously understaffed
# emotion: sadness
#
# hostess busboy running frantically restaurant sad watch try care guests
# emotion: sadness
#
# maid service did n't come room late afternoon
# emotion: neutral
#
# arriving shampoo bottle room opened looked like shampoo missing
# emotion: sadness
#
# usually hotel problems just
# emotion: sadness
#
# bad nice hotel
# emotion: sadness
#
# recommed andra
# emotion: neutral
#
# grew seattle moved away years
# emotion: neutral
#
# recommend andra friends family visit andra hippest hotel town best rooms.i recently stayed march birthday/st
# emotion: joy
#
# patrick day
# emotion: neutral
#
# booked one-bedroom corner suite screaming deal spring seattle 369 night yes suite 400 spring seattle
# emotion: neutral
#
# love hotel rooms
# emotion: neutral
#
# ample space wonderful decor comfy chenille blankie
# emotion: joy
#
# flat-panel televisions.i similar suites westin fairmont price paid price andra andra wins hands-down
# emotion: joy
#
# bathrooms think totally awesome
# emotion: joy
#
# love original tile bathroom floor love ample lighting bathroom esp nightlight
# emotion: joy
#
# let talk desk
# emotion: neutral
#
# compliments outfit immediately wins brownie points
# emotion: joy
#
# love andra
# emotion: neutral
#
# updated trendy hotel perfect location
# emotion: surprise
#
# stayed andra times great experience
# emotion: joy
#
# rooms updated clean spacious
# emotion: neutral
#
# staff friendly helpful
# emotion: neutral
#
# restaurant convenient choices food vacinity
# emotion: neutral
#
# prefer stay andra anytime seattle
# emotion: neutral
#
# not quite title review basically sums recent stay andra
# emotion: neutral
#
# overall satisfied stay got deep discount left wondering listed small luxury hotels world.we lux king corner suite suite quite spacious quiet did restful sleep
# emotion: surprise
#
# beds/linens soft comfortable brought extra pillows requested
# emotion: neutral
#
# plenty storage suite 2 closets set drawers plus generously-sized night tables plus.however sofa disappointing cheap construction sagging middle fairly uncomfortable sit watch tv
# emotion: sadness
#
# armchair seriously needed recovering edges worn dirty frayed
# emotion: sadness
#
# suite overhaul soon noticed chipped paint plus chipped scratched furniture
# emotion: surprise
#
# carpets felt bit grimy overall feeling room cleaner.the bathroom small knew going having read past reviews
# emotion: sadness
#
# did not bother adequate shelves storage
# emotion: neutral
#
# like soaking tub forget
# emotion: neutral
#
# tub low overflow drain obviously designed hates baths
# emotion: sadness
#
# 5'2 not big maximum water level came lower abdomen
# emotion: neutral
#
# reclined trying soak water kept draining gave 5 minutes
# emotion: neutral
#
# shower pressure good tons hot water time day
# emotion: neutral
#
# face stockholm amenities delicious subtle white tea fragrance bottles size postage stamps cheap luxury hotel
# emotion: joy
#
# staff happy send tiring request daily basis.the staff 20-30 somethings pleasant eager
# emotion: joy
#
# feel not achieved luxury level service
# emotion: sadness
#
# simple request sent seattle times v. new york times like read local news
# emotion: neutral
#
# daily basis received new york times credit swiftly replaced seattle times request n't asking 4 days row
# emotion: surprise
#
# time asked desk person reconfirm reservation concierge left looked like handed dead fish
# emotion: disgust
#
# nitpicking expect maybe motel 6 v. luxury hotel
# emotion: neutral
#
# actually place andra slightly 3 star hotel not luxury level
# emotion: surprise
#
# staff accomodating pleasant room ok. stay got low rate not stay pay high season rate approx 480.00 felt service room not worth
# emotion: joy
#
# okay amazing lost bags
# emotion: surprise
#
# stayed friend wedding
# emotion: surprise
#
# high expectations going hotel not impressed checked
# emotion: surprise
#
# rooms small cramped
# emotion: sadness
#
# bathrooms small
# emotion: neutral
#
# stayed sheraton seattle previous nights paid price far impressed accommodations sheraton better accommodations bigger rooms bigger bathrooms cleaner upscale.during checkout checked bags hotel lunch
# emotion: surprise
#
# came bags nobody able
# emotion: sadness
#
# ended having ask bellboy basement bags not ended finding locked random room basement
# emotion: surprise
#
# staff pretty worthless bags lost
# emotion: sadness
#
# favorite hotel work responsibilities taken seattle 4-6 times year years stayed hotel andra dozen times 2-5 nights stay
# emotion: neutral
#
# time period travel extensively domestically internationally favorite hotel
# emotion: joy
#
# apart superb location seam downtown seattle bell town wonderful restaurants location not beat view non-convention style hotel contemporary furnishings comfortable beds efficient workspaces easy internet access excellent restaurants accessible lobby
# emotion: joy
#
# breakfasts lola just outstanding assaggio terrific italian place dinner street excellent lunch dinner dahlia lounge
# emotion: joy
#
# staff particularly friendly responsive happy accommodate reasonable requests favors
# emotion: joy
#
# not news junkie really value fact ask presto free copy new york times including sunday
# emotion: neutral
#
# door morning
# emotion: neutral
#
# great stay
# emotion: joy
#
# just returned home great stay andra
# emotion: joy
#
# travelling single woman business like andra great safe location easily walk shopping restaurants business district
# emotion: joy
#
# staff welcoming check-in acknowledged returned end work day
# emotion: neutral
#
# room comfortable showed attention
# emotion: neutral
#
# not hesitate stay
# emotion: fear
#
# loved andra
# emotion: joy
#
# visited andra stayed nights
# emotion: neutral
#
# wonderful hotel feel special moment checked
# emotion: joy
#
# older couple enjoy quiet atmosphere
# emotion: joy
#
# lobby restaurant animated problem smelled delicious
# emotion: joy
#
# greet door desk
# emotion: surprise
#
# room small did not request large room
# emotion: neutral
#
# bathroom perfect super comfortable bathtub
# emotion: neutral
#
# bed bedding wonderful
# emotion: joy
#
# website check pillows
# emotion: neutral
#
# andra clean
# emotion: neutral
#
# not lot reasonably priced restaurants sight andra blocks away large shopping mall
# emotion: sadness
#
# andra did n't mention asked dining
# emotion: neutral
#
# fine early dinner avoid dark
# emotion: neutral
#
# definitely return thank making visit happy
# emotion: joy
#
# great boutique hotel stayed hotel andra business trip october 2007. walking distance convention center prime shopping seattle
# emotion: joy
#
# hotel not directly serviced downtown airporter shuttle airport downtown hotels hotel immediately door warwick stop walk 1/2 block andra
# emotion: neutral
#
# lovely boutique hotel appears recently remodeled
# emotion: surprise
#
# modern lobby cozy fireplace
# emotion: neutral
#
# desk staff helpful friendly
# emotion: neutral
#
# room spacious 2 queen beds sitting area bar area
# emotion: joy
#
# decor modern ikea-esque
# emotion: neutral
#
# view neighboring construction site unfortunately interestingly really heard annoying sounds construction
# emotion: surprise
#
# pretty small bathroom compared hotels nice
# emotion: surprise
#
# frette towels face stockholm bath products
# emotion: neutral
#
# small business center 2 computers printers free charge
# emotion: neutral
#
# did n't use gym ca n't comment
# emotion: sadness
#
# pay daily rate in-room wireless
# emotion: neutral
#
# lots great eating options walking distance
# emotion: joy
#
# restaurant lobby lola amazing
# emotion: joy
#
# tom douglas establishment mediterranean theme definitely lived hype
# emotion: neutral
#
# tom douglas restaurant street dahlia lounge amazing donuts menu dessert served warm marscarpone cheese green apple butter
# emotion: joy
#
# amazing
# emotion: joy
#
# adjacent dahlia bakery great cup morning coffee pastry
# emotion: joy
#
# overall definitely stay visiting seattle
# emotion: neutral
#
# pretty good funky nice property booked weekend luxury link included gift cards food restaurant downstairs champagne chocolate strawberries.the rooms nice
# emotion: joy
#
# quite spacious beautiful linens
# emotion: joy
#
# frette towels face stockholm toiletries
# emotion: neutral
#
# gave 4* thought service ok not spectacular
# emotion: surprise
#
# nothing wrong not particularly friendly helpful hotel costs 200 night.the restaurant downstairs good busy locals
# emotion: joy
#
# tom douglas pizza restaurant fabulous
# emotion: joy
#
# block 2 away
# emotion: neutral
#
# im not sure open stayed andra subsequently visited restaurant great easy walk central shopping area 5 blocks pike place market
# emotion: surprise
#
# walked seahawks game
# emotion: neutral
#
# block 2 felt bit uneasy dark homeless people doorways fine
# emotion: fear
#
# probably n't walk female
# emotion: neutral
#
# nice weekend lovely intimate hotel
# emotion: joy
#
# nice hotel nice location stayed hotel andra night quick stop seattle start family vacation
# emotion: joy
#
# nice clean hotel exceptional service
# emotion: joy
#
# rooms bed comfortable exception airconditioning bit noisy
# emotion: sadness
#
# bathroom small clean
# emotion: neutral
#
# stay travelling kids longer stay definately rooms
# emotion: neutral
#
# great hotel avoid t-mobile hotspot hotel great stayed
# emotion: joy
#
# friendly staff great location rooms really nice large
# emotion: joy
#
# downside t-mobile hotspot drastically overcharged acted like doing favor rebating 1/2 overcharged pay double
# emotion: neutral
#
# advice use wired internet hotel run hotel not t-mobile
# emotion: neutral
#
# fine hotel pretty good best thing size rooms really spacious separate large closet area kitchenette area
# emotion: joy
#
# right heart downtown walk pretty centre/capitol hill
# emotion: neutral
#
# reception staff little bit snippish nothing bad
# emotion: anger
#
# hotel restaurant ca n't remember right lobby served good breakfast staff v friendly helpful
# emotion: joy
#
# experience good
# emotion: neutral
#
# comfortable great personal service hotel lovely oasis peace calm
# emotion: joy
#
# service competent not overbearing
# emotion: sadness
#
# upgraded suite n't know loved having extra sitting room
# emotion: surprise
#
# decor uncluttered warm inviting bathroom actually place stuff
# emotion: neutral
#
# sunday morning lobby inviting fireplace burning lovely ambience spite modern/industrial decor
# emotion: joy
#
# excellent stay great hotel great staff stayed hotel andra 4 nights negative point noisy a/c unit
# emotion: joy
#
# rest terrific great room great staff especialy valet/doormen
# emotion: joy
#
# n't forget eat lola
# emotion: neutral
#
# not food exceptional service flawless
# emotion: surprise
#
# great location just far away crowds waterfront close walk great restaurants local attractions
# emotion: joy
#
# time booking rooms 2 queen beds available
# emotion: neutral
#
# arrival asked king room
# emotion: neutral
#
# upgraded accommodate bed type
# emotion: neutral
#
# rooms spacious small bathrooms okay area getting dressed drying hair
# emotion: neutral
#
# stayed 2 nights booked night return trip
# emotion: neutral
#
# received upgrade
# emotion: neutral
#
# staff helpful onsite restaurants good
# emotion: neutral
#
# comfortable stay hotel andra just returned home business trip ended nights hotel andra
# emotion: joy
#
# booked andra suite just right size
# emotion: neutral
#
# loved walk closet nice bags flipped open room
# emotion: neutral
#
# couch super comfy watching tv end day
# emotion: joy
#
# touches liked length dressing mirror ca n't beat comfortable bed
# emotion: sadness
#
# bathroom tiny despite modern upgrades dated water shower got hot prefer
# emotion: sadness
#
# not missed restaurant downstairs
# emotion: sadness
#
# ate 3 times delicious especially order donuts mascarpone cheese
# emotion: joy
#
# bar makes great drinks
# emotion: joy
#
# good service great beds over-priced stayed hotel andra nights
# emotion: joy
#
# staff helpful stay
# emotion: neutral
#
# place beautifully decorated rooms average size
# emotion: joy
#
# place quite clean
# emotion: neutral
#
# bed wonderful
# emotion: joy
#
# usually terrible night sleep hotel great sleep nights row
# emotion: fear
#
# did not hotel noisy husband did
# emotion: sadness
#
# did hotel bit priced got
# emotion: surprise
#
# billed small luxury hotel really did n't different decor
# emotion: surprise
#
# location great walked hotel
# emotion: joy
#
# breakfast lola adjoining restaurant excellent
# emotion: joy
#
# doughnuts
# emotion: neutral
#
# raving
# emotion: neutral
#
# overall enjoyed stay time stay expensive
# emotion: joy
#
# poor service good reviews andra gets makes wonder stayed place.my wife spent nights honeymoon seattle andra
# emotion: surprise
#
# wish days trip did n't anti-climax.having read previous bad review hotel contacted andra advance reserve room high floor away elevators soundproofing non-existent.what room did
# emotion: surprise
#
# lower floor opposite elevator
# emotion: neutral
#
# willing away elevator floor.our package included champagne truffles arrival
# emotion: neutral
#
# truffles did n't arrive final night complaints desk.i handed item clothing laundered
# emotion: sadness
#
# came ruined.overall andra great looking hotel marks poor service.the saving grace adjacent lola restaurant serves great food
# emotion: sadness
#
# glad chose andra truly minute booking morning day arrived san francisco portland
# emotion: neutral
#
# stayed night traveling victoria bc andra charming worthy praise gotten
# emotion: joy
#
# valet/door attendant little slow service door haphazard day desk friendly helpful not
# emotion: neutral
#
# did great seattle map given tourists questions things located
# emotion: surprise
#
# decor comfortable touches nyc chic.we got studio king bed couch far end large room sliver puget sound window room reminded nyc high end studio apartment modern spotlessly clean right fantastic frette linens bed outstandingly comfortable tiny nicely appointed bathroom
# emotion: joy
#
# bathroom really tiny no place store hold toiletries important great soaps toiletries bedroom tv terrific sized flat screen view bed couch
# emotion: surprise
#
# did n't eat bar restaurant nightlife definitely evident ate anthony waterfront night great definitely try hotel restaurant time.so close downtown area quick walk seaport shopping n't think reason not return time
# emotion: surprise
#
# not world class hotel chose hotel trip girlfriend listed small luxury hotels world registry
# emotion: surprise
#
# disappointed hotels listed slhw perfect way hotel andra truly average
# emotion: sadness
#
# fine average
# emotion: neutral
#
# stayed 5 nights
# emotion: neutral
#
# rooms fine not luxurious
# emotion: neutral
#
# bathroom tiny
# emotion: neutral
#
# problems no works age 25. really need seasoned professional concierge knows doing
# emotion: neutral
#
# just example check early morning departure pay reasonable hefty 5 nights turning away ask desk clerk map airport
# emotion: neutral
#
# proceeds argue need map easy airport downtown seattle
# emotion: neutral
#
# finally says guess print mapquest
# emotion: neutral
#
# no-brainer
# emotion: neutral
#
# super place stay
# emotion: neutral
#
# treat book andra business trip
# emotion: neutral
#
# spell bad luck finding good hotels recent previous trips pleasure stay spacious clean quiet hotel friendly professional staff
# emotion: sadness
#
# especially liked wonderfully comfortable bed cool bathroom
# emotion: joy
#
# guys manning door helpful cute
# emotion: joy
#
# loved modern decor interior
# emotion: joy
#
# pleased hotel centrally located shopping dinning seattle downtown district waterfront
# emotion: joy
#
# picky clean freak likes nice things fully recommend andra hesitation
# emotion: fear
#
# seattle gem
# emotion: neutral
#
# great updated historic hotel great hotel great location
# emotion: joy
#
# walk pike market space needle monorail waterfront shopping bars restaurants no time flat
# emotion: joy
#
# hotel does not amenities luxury hotels in-house spa pool lot character style old luxury hotels like drake chicago
# emotion: neutral
#
# unlike reviews hotel staff extremely friendly helpful maybe management responded negative feedback
# emotion: neutral
#
# complaints street noise weekday commute hours windows need better insulation room keys kept demagnetizing
# emotion: neutral
#
# suite spacious comfortable
# emotion: neutral
#
# fact slept comfortable cozy bed
# emotion: neutral
#
# bathroom small cute art deco-like
# emotion: joy
#
# decor general new ikea inspired
# emotion: neutral
#
# valet parking quick efficient friendly asked needed directions
# emotion: neutral
#
# highly recommend lola located lobby breakfast nightcap
# emotion: neutral
#
# absolutely no onion smell
# emotion: disgust
#
# definitely stay
# emotion: neutral
#
# make reservation
# emotion: neutral
#
# wo n't disappointed
# emotion: sadness
#
# news conde nast traveler magazine recently listed hotel andra hot hotel 2005 really intrigued friend planned wedding seattle announced booked rooms immediately directly hotel using fax number website
# emotion: surprise
#
# hotel lobby bar rooms decorated hip modern welcoming scandanavian style
# emotion: joy
#
# bar/restaurant happening place spilling lobby night stylish young people drinking talking
# emotion: joy
#
# quiet no boorish behavior
# emotion: fear
#
# party booked suite 299/night double 159/night
# emotion: neutral
#
# suites separate rooms advertized n't expect lot privacy door rooms louvered
# emotion: neutral
#
# group family merely good friends adequate degree separateness
# emotion: joy
#
# rooms comfortable size clean well-furnished noticeable wear tear bathrooms bit small
# emotion: joy
#
# beds super-comfortable guests provided great number spa-type towels
# emotion: neutral
#
# flat-screen tv rooms
# emotion: neutral
#
# business center small desk-top printer did not work stay
# emotion: sadness
#
# online e-mail free desktop lobby use guests
# emotion: neutral
#
# entire hotel wi-fi 10.00 day
# emotion: neutral
#
# say real estate best hotel location location location
# emotion: neutral
#
# blocks major shopping blocks pike place market great restaurants walking
# emotion: joy
#
# ralph corner 40 yards away airporter connector bus 17 roundtrip compared 56 taxi picks drops 30 minutes
# emotion: neutral
#
# monorail space needle experience music project blocks away
# emotion: neutral
#
# recommend hotel andra reservation maybe reservation
# emotion: neutral
#
# make time heading seattle
# emotion: neutral
#
# andra recovers near miss chose andra birthday-weekend getaway serene modern upscale atmosphere special different
# emotion: joy
#
# sadly disappointed roof construction noise woke 7 holiday morning
# emotion: sadness
#
# staff courteous immediately moved different floor upgraded room left feeling uncertainty
# emotion: fear
#
# let happen
# emotion: neutral
#
# uncertainty totally erased got wonderful return letter administration stating construction crew broken contract hours work
# emotion: anger
#
# sent hotel luscious robes soften blow
# emotion: joy
#
# certainly try based great response got
# emotion: neutral
#
# hoped location andra ca n't beat
# emotion: neutral
#
# walking nearly sight seattle breeze
# emotion: anger
#
# strain compare boutique hotel visited west coast
# emotion: surprise
#
# amenities lackluster weightroom like afterthought staff astoundingly incompetent insincere
# emotion: fear
#
# know nothing property city management hiding alcove desk
# emotion: neutral
#
# overall money burn looking staff challenge patience not disappointed
# emotion: sadness
#
# wether equals happy stay location
# emotion: joy
#
# model modern hotel andra suite large bright attractively furnished
# emotion: joy
#
# art deco modern touches
# emotion: neutral
#
# saw room large flat screen tv wall.and bed comfortable
# emotion: surprise
#
# negative room closet larger.the hotel well-located blocks pike place market nordstrom macy's.the hotel convenient news stand/gift shop plenty stores nearby
# emotion: joy
#
# did n't concierge did n't matter guests.we definitely stay
# emotion: neutral
#
# checked tripadvisor place terrible just reviewers tripadvisor indicates
# emotion: fear
#
# couple reviews looks like written hotel staff exact opposite real experience.from low quality toiletries inconsistent house keeping property rated 3 star
# emotion: sadness
#
# attempts property unique look succeeds making gag incredibly poor taste decorated
# emotion: sadness
#
# like big joke you.the hotel noisy rooms tiny decor ugly staff average isolated rest seattle view overrated nearby train noisy room stinky
# emotion: sadness
#
# lounge expensive 10 drinks good view absolutely no character
# emotion: neutral
#
# experiencing boring lounge decided not bother restaurant instead cabbed city food.i recommend using tripadvisor pick 4 star hotel instead foolish like pay consequences
# emotion: sadness
#
# fact probably pick highly rated 3 star hotel fare times better did
# emotion: neutral
#
# nice rate bed did n't really problem property
# emotion: neutral
#
# booked hotwire 118
# emotion: neutral
#
# showed upgraded room queen sized bed king sized bed
# emotion: surprise
#
# bed good quality
# emotion: neutral
#
# view water great.the decor definitely inspired great outdoors totally fine 2-night stay
# emotion: joy
#
# meetings downtown just couple nice 20-minute walk needed
# emotion: neutral
#
# bed comfortable bathroom nice decent-sized
# emotion: joy
#
# bathroom amenities n't great quality however.comparisons hotels unfair opinion
# emotion: anger
#
# yes nice room downtown seattle spend 2-3 times
# emotion: neutral
#
# business owner like travel expenses deducted line edgewater great find.the biggest sour note second night room occupied drunk threesome came room 2 proceeded talk loudly hours
# emotion: sadness
#
# overpriced not great disappointing property
# emotion: sadness
#
# setting stilts hanging water fabulous ends.the decor odd incongruous impressions seattle
# emotion: joy
#
# log cabin-ish better suited ski lodge vermont colorado
# emotion: neutral
#
# requested water-facing room check-in told cost 50 dollars paid
# emotion: surprise
#
# having forked 300 dollars night declined took city facing room
# emotion: sadness
#
# irritating colleague booked room rate agent checked right behund got water facing room no extra charge asking notwithstanding odd decor hotel looks tired worn
# emotion: sadness
#
# room abysmally small amazed american travellers accept rooms size knowing spacious hotels general
# emotion: surprise
#
# not large person not problem typically smaller rooms finds eurpoean continent
# emotion: neutral
#
# barely space double bed sharing felt claustrophobic
# emotion: fear
#
# city-facing rooms railway line busy level crossing clanging bell time train passes
# emotion: neutral
#
# happens day night
# emotion: neutral
#
# rooms need twice size sound-proofed
# emotion: neutral
#
# 3 nights trot chaicago seattle san francisco far worst value 3 cities
# emotion: disgust
#
# lot better price seattle
# emotion: neutral
#
# cozy lodge like reviewers site boyfriend ended edgewater bidding 4-star hotel seattle
# emotion: joy
#
# really enjoyed stay
# emotion: joy
#
# room small well-appointed comfortable linen cozy fireplace cute teddy-bear bed wonderful bathroom spa toiletries rainfall shower-head
# emotion: joy
#
# possible room overlooking harbor view breathtaking best hotel
# emotion: joy
#
# location great famous landmarks seattle walking distance
# emotion: surprise
#
# thing watch cosly parking fee comes 32/night overnight parking plus tip
# emotion: neutral
#
# said definelty stay sans rental car
# emotion: neutral
#
# terrible accomodations ruined impression seattle decided stay hotel hearing work colleague great place stay waterfront seattle
# emotion: fear
#
# booking stay checked website
# emotion: neutral
#
# talk misleading pictures
# emotion: anger
#
# got hotel sunday afternoon checked immediately disappointed got hotel hallway room
# emotion: sadness
#
# dirty reminded old college dormitory
# emotion: disgust
#
# hotel room did not overlook water train tracks small clean no drawers clothing no desk work
# emotion: surprise
#
# additionally hotel loaded folks spent weekend hemp fest
# emotion: joy
#
# not recommend fooled website
# emotion: fear
#
# heard lady met town dinner highly recommends inn black market alexis wish met earlier think different seattle experience
# emotion: surprise
#
# time
# emotion: neutral
#
# n't waste money edgewater
# emotion: neutral
#
# waterview room balcony worth money
# emotion: neutral
#
# husband stayed edgewater recent visit seattle
# emotion: neutral
#
# booked room travel agent not sure expect
# emotion: surprise
#
# outside hotel not look room stayed spectacular
# emotion: surprise
#
# wow view
# emotion: surprise
#
# waterfront room private balcony overlooking elliott bay
# emotion: surprise
#
# heard occasional seagulls
# emotion: neutral
#
# evening sunsets breathtaking
# emotion: joy
#
# sailboats cargo boats tugboats cruising bay
# emotion: neutral
#
# view olympic mountains downtown seattle
# emotion: neutral
#
# dont know rooms perfect
# emotion: neutral
#
# note like add day appeared commons areas hotel little dirty maybe high occupancy day clean tidy
# emotion: neutral
#
# come
# emotion: neutral
#
# husband visited seattle time dec. 2006. celebrating 1st anniversary amazing time
# emotion: joy
#
# edgewater perfect
# emotion: neutral
#
# staff best experienced
# emotion: neutral
#
# hotel runs shuttles town hour day n't want walk just head downstairs hour
# emotion: neutral
#
# did tip driver loved doing great information reservations local restaurant taking shopping just called hotel gave info
# emotion: surprise
#
# enjoyed walking nearby restaurants enjoyed walk pike market n't recommend walking older folks fairly good distance n't great shape pleasant walk
# emotion: joy
#
# waterfront room 1st floor interesting winter
# emotion: surprise
#
# waves crashing right basically loved
# emotion: surprise
#
# probably moved higher did n't enjoy crashing waves asked
# emotion: sadness
#
# stay problem tv
# emotion: neutral
#
# minutes repair man fixing bought movie inconvenience.the ambiance wonderful winter stay
# emotion: joy
#
# loved entrance huge fireplace really loved rooms.i 100 recommend hotel visiting seattle
# emotion: joy
#
# priceline deal stayed 2 nights visiting family
# emotion: neutral
#
# booked priceline reading online reviews somewhat pleased stay
# emotion: joy
#
# book priceline 2 twin beds barely long 6ft heating dificult operate
# emotion: neutral
#
# fireplace nice
# emotion: joy
#
# parking 28/day pretty steap hard offsite parking
# emotion: surprise
#
# moring told upgrade king bed water room extra 50 night
# emotion: surprise
#
# did better room
# emotion: neutral
#
# great view larger bed
# emotion: neutral
#
# just away cruise terminal door alaskian cruiseship view day
# emotion: neutral
#
# stayed seattle sheraton following night 180 priceline liked hotel better
# emotion: surprise
#
# not family place family wanted spend couple days seattle
# emotion: sadness
#
# children ages 4 9. seen ocean wanted stay water
# emotion: surprise
#
# stayed room like
# emotion: neutral
#
# room 3 times price 5 hotels stayed vacation far tiniest
# emotion: neutral
#
# hidden costs annoying
# emotion: anger
#
# fireplace looked nice n't control temperature room
# emotion: neutral
#
# husband slipped bar night drink kids went sleep
# emotion: neutral
#
# female bartender pleasant helpful
# emotion: joy
#
# bellman people place time day unless wallets
# emotion: neutral
#
# definitely did not feel hotel worth money
# emotion: joy
#
# impressed entranced edgewater great location close excellent restaurants newly remodeled elliot fantatstic beautiful walking/jogging waterfront park door.great service bellman offered shuttle restaurants car arrived fast desk moved rooms quickly bit noisy fog horn/train bellman got cup hot tea morning no charge waiting jogging partner
# emotion: surprise
#
# helpful wanting please.the room fantastic all-new bathroom slate floors shower big claw foot tub shoji screens sit bath look water flip-on fireplace furry footrest comfy chairs good size desk adequate plugs wifi 7/hr 10/day amenities room iron/board coffee maker hairdryer lighted makeup mirror high quality towels bedding shampoo
# emotion: joy
#
# bar/restaurants gorgeous water great meeting place business pleasure.the price wow just 149/night hotwire.the smell
# emotion: joy
#
# lookout moldy smell tripadvisor reviews none.only complaints exercise room small 3 4 cardio machines
# emotion: sadness
#
# accessible 24 hours
# emotion: neutral
#
# cosy lodge hotel location right water place
# emotion: neutral
#
# regretably renovation work waterside facia meant comfy lounge area open sofa windows sheeted stayed early november 07
# emotion: joy
#
# views obtained cosy modern bar area.the hotel lodge style modern trendy bar restaurant despite opposites actually attract.on arrival expense valet parking eased large pit
# emotion: joy
#
# service hotel great especially concierge knew stuff.we upgraded waterfront room deal hotel
# emotion: joy
#
# room small maybe crammed furniture big lounge chairs small desk chair just appeared way.the theme sitting cosy fireplace gas fired log easily controlled
# emotion: surprise
#
# great just sit robe glass wine enjoy sea view not sure ambience overlooking car park noisy main road glad upgraded.the bathroom large walk-in stoned-tiled shower great toiletries
# emotion: joy
#
# fantastic shower water pressure refresh dead.room service poor food arrived cooked not appetising
# emotion: joy
#
# additionally lobby areas looking little worn tired room viewed critical eye.very enjoyable not far main city shops albeit 5cab ride ideally necessary.would recommend hotel want relaxing stay cosy room make use hotel views
# emotion: joy
#
# fabulous hotel seattle fantastic hotel pricey
# emotion: joy
#
# hotel water downtown seattle worth price
# emotion: neutral
#
# restaurant view spectacular- cant beat
# emotion: joy
#
# rooms nice nothing spectacular
# emotion: surprise
#
# staff accomodating friendly.great location
# emotion: joy
#
# close infamous pike place market
# emotion: neutral
#
# harbor view room
# emotion: neutral
#
# really enjoyed stay edgewater
# emotion: joy
#
# things pricey pay
# emotion: neutral
#
# amazing harbor view room hang water windows open
# emotion: neutral
#
# afternoon hand fed seagulls staff great
# emotion: joy
#
# encountered desk maintaince smiled said hello
# emotion: joy
#
# nice customer service taken seriously
# emotion: neutral
#
# slight drawback location n't easy walks
# emotion: sadness
#
# closet places eat shop pretty steep hill
# emotion: surprise
#
# good news edgewater shuttle drop downtown pick
# emotion: joy
#
# water near pike market great hotel wonderful location peer near shopping art schools great atmosphere
# emotion: joy
#
# loved restaurant water
# emotion: joy
#
# solidly good
# emotion: neutral
#
# stayed night business place daylight sadly
# emotion: sadness
#
# missed view did not mind city-side room
# emotion: neutral
#
# room little small eentsy-teentsy sized tv perfectly adequate
# emotion: neutral
#
# great mattress linens
# emotion: neutral
#
# loved bathroom stone floors shower
# emotion: neutral
#
# great service desk arranging transportation airport 4:30 a.m. thought price 279 little pricey got
# emotion: surprise
#
# return edgewater visit excellent return
# emotion: joy
#
# room accommodations tight fit people clean housekeeper attentive details
# emotion: neutral
#
# desk restaurant staff bell desk friendly informative
# emotion: neutral
#
# water view guestroom worth paying
# emotion: neutral
#
# food restaurant pricey impeccable service worth
# emotion: joy
#
# bell staff graciously accommodated request complimentary shuttle service pikes market
# emotion: joy
#
# spent total 6 nights edgewater nothing complain
# emotion: anger
#
# edgewater walking distance downtown number good restaurants
# emotion: joy
#
# enjoyed ambiance lobby
# emotion: joy
#
# thank staff edgewater wonderful visit
# emotion: joy
#
# return someday
# emotion: neutral
#
# nice scene noisy rooms loved ocean scene seagulls giant tv sets rooms walls bothered
# emotion: anger
#
# asked personell noisy neighbours not experience change.the kitchen great lounge cool.not bad
# emotion: sadness
#
# worth try
# emotion: neutral
#
# average hotel high price stayed 1 night city view want car park bed nice comfortable rooms just little high priced
# emotion: neutral
#
# nice view lobby loan want eat restraunt
# emotion: neutral
#
# absolutly worst booked room wife trip seattle edgewater.we ended having plane delays mechanical juneau flt 75. called edgewater inform late arrival
# emotion: sadness
#
# ended arriving late flt 66. finally reached edgewater room not reserved
# emotion: surprise
#
# main issues heating cold night general condition room run
# emotion: sadness
#
# asked desk relocate room
# emotion: neutral
#
# informed no rooms available stay
# emotion: sadness
#
# early morning asked moved asked room accepting
# emotion: neutral
#
# informed room not available 4:00 p.m. desk wanted leave bags
# emotion: sadness
#
# not comfortable accepting room sight unseen charges accrueing day
# emotion: fear
#
# wife agreed time cancel staythe edgewater refused adjust credit card contacted wwte online reimbursement
# emotion: sadness
#
# received adjustment charges wwte
# emotion: neutral
#
# night business trip seattle
# emotion: neutral
#
# noisy room room beautiful killer view right ballrooms wedding reception going
# emotion: joy
#
# wife took 40th birthday supposed romantice evening away kids
# emotion: surprise
#
# got noisy 11:00 evening listening muffled 70 music people dancing
# emotion: sadness
#
# manager n't budge giving compensate bad experience
# emotion: anger
#
# did offer smaller room
# emotion: neutral
#
# stay
# emotion: neutral
#
# stay friday saturday night ask stay far away ballroom possible
# emotion: neutral
#
# beautiful view-disappointing service stayed edgewater 15th anniversary
# emotion: joy
#
# paid small fortune beautiful waterfront room
# emotion: joy
#
# unfortunately water bay no water room
# emotion: sadness
#
# apparently replacing plumbing no told
# emotion: surprise
#
# nothing said reserved checked
# emotion: neutral
#
# went upstairs shower change dinner no water n't flush toilet
# emotion: sadness
#
# inquired desk manager just said just wait awhile
# emotion: neutral
#
# sure got water hour
# emotion: neutral
#
# got excited got ready shower
# emotion: surprise
#
# turned water got brown goop
# emotion: surprise
#
# ran awhile cleared no hot water
# emotion: sadness
#
# inquired told soon
# emotion: neutral
#
# couple hours tried
# emotion: neutral
#
# lukewarm
# emotion: neutral
#
# called desk assured hot
# emotion: neutral
#
# finally hotel engineer come room
# emotion: neutral
#
# turned water blast stood 10 minutes pj agree n't hot
# emotion: surprise
#
# no explanation promise fix
# emotion: neutral
#
# thought leaving hotel time late
# emotion: sadness
#
# manager nothing offer free breakfast coupons
# emotion: neutral
#
# day encountered new manager refunded night nothing really makes miserable stay
# emotion: sadness
#
# supposed relaxing romantic night away kids stressful miserable stay
# emotion: sadness
#
# unique exceptional
# emotion: neutral
#
# loved stay
# emotion: joy
#
# husband spent days edgewater amazed
# emotion: surprise
#
# sitting pier felt like ship
# emotion: fear
#
# lobby having glass walls comfy chairs fireplace
# emotion: joy
#
# decor unique lodge like look
# emotion: neutral
#
# room small romantic cozy
# emotion: joy
#
# clean nice fireplace bear stool balcony sat watching ferries ships planes trains seagul ate hand
# emotion: neutral
#
# shuttle great victoria clipper door waterfront
# emotion: neutral
#
# different loved restaurant dinner small late snack
# emotion: neutral
#
# negative point staff kind responsive not good providing directions information area
# emotion: neutral
#
# time stayed alexis loved hotel
# emotion: joy
#
# friendliest hotel america
# emotion: neutral
#
# husband stayed sorrento cruise really ended holiday high
# emotion: surprise
#
# moment arrived feel really special
# emotion: joy
#
# nothing trouble staff
# emotion: sadness
#
# hotel real charm place tasteful
# emotion: joy
#
# bedrooms wonderfrul evenings beautiful fireside room play jazz lovely place unwind relax busy day
# emotion: joy
#
# travelled world thing lacking hotels nowadays complete indifference staff wo n't sorrento run people really care stay enjoyable
# emotion: sadness
#
# recommend hotel seattle
# emotion: neutral
#
# just wish hotels run manner
# emotion: neutral
#
# location ideal courtesy car city like
# emotion: neutral
#
# concierge members staff really went way helpful recommending places visit would'nt crowded unfortunately arrived weekend public holiday
# emotion: sadness
#
# town visitors love hotel town visitors love old wood traditional ambience good food hotel
# emotion: joy
#
# reported stay comfy service good
# emotion: joy
#
# not right downtown blocks easy walking quick taxi ride away
# emotion: neutral
#
# hotel town car service
# emotion: neutral
#
# hosted major event daughter wedding guests happy
# emotion: joy
#
# incidentally hunt club catered buffet talk relatives
# emotion: joy
#
# oh love place
# emotion: surprise
#
# lucky win gift certificate sorrento hotel beautiful place
# emotion: joy
#
# thought look noses given donated gift certificate desk treated did concierge.the room lovely little small french press coffee actually not bad
# emotion: surprise
#
# ...
#     407 def call(self, hidden_states: tf.Tensor, input_tensor: tf.Tensor, training: bool = False) -> tf.Tensor:
# --> 408     hidden_states = self.dense(inputs=hidden_states)
#     409     hidden_states = self.dropout(inputs=hidden_states, training=training)
#     410     hidden_states = self.LayerNorm(inputs=hidden_states + input_tensor)
#
# File c:\Users\admin\OneDrive - NEOM\Desktop\imdb_sentiment\.conda\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\admin\OneDrive - NEOM\Desktop\imdb_sentiment\.conda\lib\site-packages\keras\engine\base_layer.py:1089, in Layer.__call__(self, *args, **kwargs)
#    1086 namescope_stack.enter_context(tf.name_scope(name_scope))
#    1088 if not self.built:
# -> 1089     self._maybe_build(inputs)
#    1091 if self._autocast:
#    1092     inputs = self._maybe_cast_inputs(inputs, input_list)
#
# File c:\Users\admin\OneDrive - NEOM\Desktop\imdb_sentiment\.conda\lib\site-packages\keras\engine\base_layer.py:2949, in Layer._maybe_build(self, inputs)
#    2944 if not hasattr(self.build, "_is_default"):
#    2945     # Any setup work performed only once should happen in an
#    2946     # `init_scope` to avoid creating symbolic Tensors that will
#    2947     # later pollute any eager operations.
#    2948     with tf_utils.maybe_init_scope(self):
# -> 2949         self.build(input_shapes)
#    2950 # We must set also ensure that the layer is marked as built, and the
#    2951 # build shape is stored since user defined build functions may not
#    2952 # be calling `super.build()`
#    2953 Layer.build(self, input_shapes)
#
# File c:\Users\admin\OneDrive - NEOM\Desktop\imdb_sentiment\.conda\lib\site-packages\keras\layers\core\dense.py:154, in Dense.build(self, input_shape)
#     148     raise ValueError(
#     149         "The last dimension of the inputs to a Dense layer "
#     150         "should be defined. Found None. "
#     151         f"Full input shape received: {input_shape}"
#     152     )
#     153 self.input_spec = InputSpec(min_ndim=2, axes={-1: last_dim})
# --> 154 self.kernel = self.add_weight(
#     155     "kernel",
#     156     shape=[last_dim, self.units],
#     157     initializer=self.kernel_initializer,
#     158     regularizer=self.kernel_regularizer,
#     159     constraint=self.kernel_constraint,
#     160     dtype=self.dtype,
#     161     trainable=True,
#     162 )
#     163 if self.use_bias:
#     164     self.bias = self.add_weight(
#     165         "bias",
#     166         shape=[
#    (...)
#     173         trainable=True,
#     174     )
#
# File c:\Users\admin\OneDrive - NEOM\Desktop\imdb_sentiment\.conda\lib\site-packages\keras\engine\base_layer.py:705, in Layer.add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint, use_resource, synchronization, aggregation, **kwargs)
#     702 if layout:
#     703     getter = functools.partial(getter, layout=layout)
# --> 705 variable = self._add_variable_with_custom_getter(
#     706     name=name,
#     707     shape=shape,
#     708     # TODO(allenl): a `make_variable` equivalent should be added as a
#     709     # `Trackable` method.
#     710     getter=getter,
#     711     # Manage errors in Layer rather than Trackable.
#     712     overwrite=True,
#     713     initializer=initializer,
#     714     dtype=dtype,
#     715     constraint=constraint,
#     716     trainable=trainable,
#     717     use_resource=use_resource,
#     718     collections=collections_arg,
#     719     synchronization=synchronization,
#     720     aggregation=aggregation,
#     721     caching_device=caching_device,
#     722 )
#     723 if regularizer is not None:
#     724     # TODO(fchollet): in the future, this should be handled at the
#     725     # level of variable creation, and weight regularization losses
#     726     # should be variable attributes.
#     727     name_in_scope = variable.name[: variable.name.find(":")]
#
# File c:\Users\admin\OneDrive - NEOM\Desktop\imdb_sentiment\.conda\lib\site-packages\tensorflow\python\trackable\base.py:489, in Trackable._add_variable_with_custom_getter(self, name, shape, dtype, initializer, getter, overwrite, **kwargs_for_getter)
#     479   if (checkpoint_initializer is not None and
#     480       not (isinstance(initializer, CheckpointInitialValueCallable) and
#     481            (initializer.restore_uid > checkpoint_initializer.restore_uid))):
#    (...)
#     486     # then we'll catch that when we call _track_trackable. So this is
#     487     # "best effort" to set the initializer with the highest restore UID.
#     488     initializer = checkpoint_initializer
# --> 489 new_variable = getter(
#     490     name=name,
#     491     shape=shape,
#     492     dtype=dtype,
#     493     initializer=initializer,
#     494     **kwargs_for_getter)
#     496 # If we set an initializer and the variable processed it, tracking will not
#     497 # assign again. It will add this variable to our dependencies, and if there
#     498 # is a non-trivial restoration queued, it will handle that. This also
#     499 # handles slot variables.
#     500 if not overwrite or isinstance(new_variable, Trackable):
#
# File c:\Users\admin\OneDrive - NEOM\Desktop\imdb_sentiment\.conda\lib\site-packages\keras\engine\base_layer_utils.py:134, in make_variable(name, shape, dtype, initializer, trainable, caching_device, validate_shape, constraint, use_resource, collections, synchronization, aggregation, partitioner, layout)
#     127     use_resource = True
#     129 if layout is None:
#     130     # In theory, in `use_resource` is True and `collections` is empty
#     131     # (that is to say, in TF2), we can use tf.Variable.
#     132     # However, this breaks legacy (Estimator) checkpoints because
#     133     # it changes variable names. Remove this when V1 is fully deprecated.
# --> 134     return tf1.Variable(
#     135         initial_value=init_val,
#     136         name=name,
#     137         trainable=trainable,
#     138         caching_device=caching_device,
#     139         dtype=variable_dtype,
#     140         validate_shape=validate_shape,
#     141         constraint=constraint,
#     142         use_resource=use_resource,
#     143         collections=collections,
#     144         synchronization=synchronization,
#     145         aggregation=aggregation,
#     146         shape=variable_shape if variable_shape else None,
#     147     )
#     148 else:
#     149     return dtensor.DVariable(
#     150         initial_value=init_val,
#     151         name=name,
#    (...)
#     160         shape=variable_shape if variable_shape else None,
#     161     )
#
# File c:\Users\admin\OneDrive - NEOM\Desktop\imdb_sentiment\.conda\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\admin\OneDrive - NEOM\Desktop\imdb_sentiment\.conda\lib\site-packages\tensorflow\python\ops\variables.py:264, in VariableMetaclass.__call__(cls, *args, **kwargs)
#     261 @traceback_utils.filter_traceback
#     262 def __call__(cls, *args, **kwargs):
#     263   if cls is VariableV1:
# --> 264     return cls._variable_v1_call(*args, **kwargs)
#     265   elif cls is Variable:
#     266     return cls._variable_v2_call(*args, **kwargs)
#
# File c:\Users\admin\OneDrive - NEOM\Desktop\imdb_sentiment\.conda\lib\site-packages\tensorflow\python\ops\variables.py:209, in VariableMetaclass._variable_v1_call(cls, initial_value, trainable, collections, validate_shape, caching_device, name, variable_def, dtype, expected_shape, import_scope, constraint, use_resource, synchronization, aggregation, shape)
#     207 if aggregation is None:
#     208   aggregation = VariableAggregation.NONE
# --> 209 return previous_getter(
#     210     initial_value=initial_value,
#     211     trainable=trainable,
#     212     collections=collections,
#     213     validate_shape=validate_shape,
#     214     caching_device=caching_device,
#     215     name=name,
#     216     variable_def=variable_def,
#     217     dtype=dtype,
#     218     expected_shape=expected_shape,
#     219     import_scope=import_scope,
#     220     constraint=constraint,
#     221     use_resource=use_resource,
#     222     synchronization=synchronization,
#     223     aggregation=aggregation,
#     224     shape=shape)
#
# File c:\Users\admin\OneDrive - NEOM\Desktop\imdb_sentiment\.conda\lib\site-packages\tensorflow\python\ops\variables.py:202, in VariableMetaclass._variable_v1_call.<locals>.<lambda>(**kwargs)
#     185 def _variable_v1_call(cls,
#     186                       initial_value=None,
#     187                       trainable=None,
#    (...)
#     199                       aggregation=VariableAggregation.NONE,
#     200                       shape=None):
#     201   """Call on Variable class. Useful to force the signature."""
# --> 202   previous_getter = lambda **kwargs: default_variable_creator(None, **kwargs)
#     203   for _, getter in ops.get_default_graph()._variable_creator_stack:  # pylint: disable=protected-access
#     204     previous_getter = _make_getter(getter, previous_getter)
#
# File c:\Users\admin\OneDrive - NEOM\Desktop\imdb_sentiment\.conda\lib\site-packages\tensorflow\python\ops\variable_scope.py:2705, in default_variable_creator(next_creator, **kwargs)
#    2703 if use_resource:
#    2704   distribute_strategy = kwargs.get("distribute_strategy", None)
# -> 2705   return resource_variable_ops.ResourceVariable(
#    2706       initial_value=initial_value,
#    2707       trainable=trainable,
#    2708       collections=collections,
#    2709       validate_shape=validate_shape,
#    2710       caching_device=caching_device,
#    2711       name=name,
#    2712       dtype=dtype,
#    2713       constraint=constraint,
#    2714       variable_def=variable_def,
#    2715       import_scope=import_scope,
#    2716       distribute_strategy=distribute_strategy,
#    2717       synchronization=synchronization,
#    2718       aggregation=aggregation,
#    2719       shape=shape)
#    2720 else:
#    2721   return variables.RefVariable(
#    2722       initial_value=initial_value,
#    2723       trainable=trainable,
#    (...)
#    2734       aggregation=aggregation,
#    2735       shape=shape)
#
# File c:\Users\admin\OneDrive - NEOM\Desktop\imdb_sentiment\.conda\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\admin\OneDrive - NEOM\Desktop\imdb_sentiment\.conda\lib\site-packages\tensorflow\python\ops\variables.py:268, in VariableMetaclass.__call__(cls, *args, **kwargs)
#     266   return cls._variable_v2_call(*args, **kwargs)
#     267 else:
# --> 268   return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#
# File c:\Users\admin\OneDrive - NEOM\Desktop\imdb_sentiment\.conda\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:1659, in ResourceVariable.__init__(self, initial_value, trainable, collections, validate_shape, caching_device, name, dtype, variable_def, import_scope, constraint, distribute_strategy, synchronization, aggregation, shape)
#    1656   self._init_from_proto(variable_def, import_scope=import_scope,
#    1657                         validate_shape=validate_shape)
#    1658 else:
# -> 1659   self._init_from_args(
#    1660       initial_value=initial_value,
#    1661       trainable=trainable,
#    1662       collections=collections,
#    1663       caching_device=caching_device,
#    1664       name=name,
#    1665       dtype=dtype,
#    1666       constraint=constraint,
#    1667       synchronization=synchronization,
#    1668       aggregation=aggregation,
#    1669       shape=shape,
#    1670       distribute_strategy=distribute_strategy,
#    1671       validate_shape=validate_shape,
#    1672   )
#
# File c:\Users\admin\OneDrive - NEOM\Desktop\imdb_sentiment\.conda\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:1812, in ResourceVariable._init_from_args(self, initial_value, trainable, collections, caching_device, name, dtype, constraint, synchronization, aggregation, distribute_strategy, shape, validate_shape)
#    1810 with ops.name_scope("Initializer"), device_context_manager(None):
#    1811   if init_from_fn:
# -> 1812     initial_value = initial_value()
#    1813   if isinstance(initial_value, trackable.CheckpointInitialValue):
#    1814     self._maybe_initialize_trackable()
#
# File c:\Users\admin\OneDrive - NEOM\Desktop\imdb_sentiment\.conda\lib\site-packages\keras\initializers\initializers_v2.py:514, in TruncatedNormal.__call__(self, shape, dtype, **kwargs)
#     504     _ensure_keras_seeded()
#     505     return utils.call_with_layout(
#     506         self._random_generator.truncated_normal,
#     507         layout,
#    (...)
#     512         nonce,
#     513     )
# --> 514 return self._random_generator.truncated_normal(
#     515     shape, self.mean, self.stddev, dtype, nonce
#     516 )
#
# File c:\Users\admin\OneDrive - NEOM\Desktop\imdb_sentiment\.conda\lib\site-packages\keras\backend.py:2142, in RandomGenerator.truncated_normal(self, shape, mean, stddev, dtype, nonce)
#    2140     if nonce:
#    2141         seed = tf.random.experimental.stateless_fold_in(seed, nonce)
# -> 2142     return tf.random.stateless_truncated_normal(
#    2143         shape=shape, mean=mean, stddev=stddev, dtype=dtype, seed=seed
#    2144     )
#    2145 return tf.random.truncated_normal(
#    2146     shape=shape,
#    2147     mean=mean,
#    (...)
#    2150     seed=self.make_legacy_seed(),
#    2151 )
#
# File c:\Users\admin\OneDrive - NEOM\Desktop\imdb_sentiment\.conda\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\admin\OneDrive - NEOM\Desktop\imdb_sentiment\.conda\lib\site-packages\tensorflow\python\util\dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\admin\OneDrive - NEOM\Desktop\imdb_sentiment\.conda\lib\site-packages\tensorflow\python\ops\stateless_random_ops.py:816, in stateless_truncated_normal(shape, seed, mean, stddev, dtype, name, alg)
#     814 stddev = ops.convert_to_tensor(stddev, dtype=dtype, name="stddev")
#     815 key, counter, alg = _get_key_counter_alg(seed, alg)
# --> 816 rnd = gen_stateless_random_ops_v2.stateless_truncated_normal_v2(
#     817     shape, key=key, counter=counter, dtype=dtype, alg=alg)
#     818 result = math_ops.add(rnd * stddev, mean, name=name)
#     819 tensor_util.maybe_set_static_shape(result, shape)
#
# File c:\Users\admin\OneDrive - NEOM\Desktop\imdb_sentiment\.conda\lib\site-packages\tensorflow\python\ops\gen_stateless_random_ops_v2.py:630, in stateless_truncated_normal_v2(shape, key, counter, alg, dtype, name)
#     628 if tld.is_eager:
#     629   try:
# --> 630     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     631       _ctx, "StatelessTruncatedNormalV2", name, shape, key, counter, alg,
#     632       "dtype", dtype)
#     633     return _result
#     634   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
